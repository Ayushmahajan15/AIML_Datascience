# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\rani mahajan\OneDrive\Desktop\pandas\movies.csv")

# %%
df
# Out:
#                                   Film      Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno    Romance  The Weinstein Company
# 1                      Youth in Revolt     Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger     Comedy            Independent
# 3                         When in Rome     Comedy                 Disney
# 4                What Happens in Vegas     Comedy                    Fox
# ..                                 ...        ...                    ...
# 65                   Gnomeo and Juliet  Animation                 Disney
# 66          Ghosts of Girlfriends Past     Comedy           Warner Bros.
# 67                    Four Christmases     Comedy           Warner Bros.
# 68                           Fireproof      Drama            Independent
# 69                           Enchanted     Comedy                 Disney
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross    Year
# ...

# %%
df.sort_values("Year")
# Out:
#                                    Film      Genre   Lead Studio  \
# 7                              Waitress    Romance   Independent
# 10  Tyler Perry's Why Did I get Married    Romance   Independent
# 31                      P.S. I Love You    Romance   Independent
# 18                   The Heartbreak Kid     Comedy     Paramount
# 51                       License to Wed     Comedy  Warner Bros.
# ..                                  ...        ...           ...
# 38                       New Year's Eve    Romance  Warner Bros.
# 43                    Midnight in Paris    Romence          Sony
# 65                    Gnomeo and Juliet  Animation        Disney
# 64                    Gnomeo and Juliet  Animation        Disney
# 69                            Enchanted     Comedy        Disney
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross    Year
# 7                 67      11.089742               89.0         $22.18   2007.0
# ...

# %%
df.sort_values("Year",ascending=False)
# Out:
#                        Film    Genre       Lead Studio  Audience score %  \
# 34                  One Day  Romance       Independent                54
# 23       Something Borrowed  Romance       Independent                48
# 11  Twilight: Breaking Dawn  Romance       Independent                68
# 8       Waiting For Forever  Romance       Independent                53
# 5       Water For Elephants    Drama  20th Century Fox                72
# ..                      ...      ...               ...               ...
# 51           License to Wed   Comedy      Warner Bros.                55
# 40         Music and Lyrics  Romance      Warner Bros.                70
# 54               Knocked Up   Comedy         Universal                83
# 62          Good Luck Chuck   Comedy         Lionsgate                61
# 69                Enchanted   Comedy            Disney                80
#
#     Profitability  Rotten Tomatoes % Worldwide Gross    Year
# ...

# %%
df2 = df.sort_values(["Year","Profitability"]).copy()

# %%
df2
# Out:
#                        Film      Genre   Lead Studio  Audience score %  \
# 51           License to Wed     Comedy  Warner Bros.                55
# 18       The Heartbreak Kid     Comedy     Paramount                41
# 62          Good Luck Chuck     Comedy     Lionsgate                61
# 36          No Reservations     Comedy  Warner Bros.                64
# 40         Music and Lyrics    Romance  Warner Bros.                70
# ..                      ...        ...           ...               ...
# 64        Gnomeo and Juliet  Animation        Disney                52
# 65        Gnomeo and Juliet  Animation        Disney                52
# 11  Twilight: Breaking Dawn    Romance   Independent                68
# 43        Midnight in Paris    Romence          Sony                84
# 69                Enchanted     Comedy        Disney                80
#
#     Profitability  Rotten Tomatoes % Worldwide Gross    Year
# ...

# %%
df2.reset_index(drop=True,inplace=True)#drop=True means it drop the index which is writen in the extra row,inplace=true means make the change in df2

# %%
df2
# Out:
#                        Film      Genre   Lead Studio  Audience score %  \
# 0            License to Wed     Comedy  Warner Bros.                55
# 1        The Heartbreak Kid     Comedy     Paramount                41
# 2           Good Luck Chuck     Comedy     Lionsgate                61
# 3           No Reservations     Comedy  Warner Bros.                64
# 4          Music and Lyrics    Romance  Warner Bros.                70
# ..                      ...        ...           ...               ...
# 65        Gnomeo and Juliet  Animation        Disney                52
# 66        Gnomeo and Juliet  Animation        Disney                52
# 67  Twilight: Breaking Dawn    Romance   Independent                68
# 68        Midnight in Paris    Romence          Sony                84
# 69                Enchanted     Comedy        Disney                80
#
#     Profitability  Rotten Tomatoes % Worldwide Gross    Year
# ...

# %%
df2["Rank"] = df2["Audience score %"].rank()

# %%
df2
# Out:
#                        Film      Genre   Lead Studio  Audience score %  \
# 0            License to Wed     Comedy  Warner Bros.                55
# 1        The Heartbreak Kid     Comedy     Paramount                41
# 2           Good Luck Chuck     Comedy     Lionsgate                61
# 3           No Reservations     Comedy  Warner Bros.                64
# 4          Music and Lyrics    Romance  Warner Bros.                70
# ..                      ...        ...           ...               ...
# 65        Gnomeo and Juliet  Animation        Disney                52
# 66        Gnomeo and Juliet  Animation        Disney                52
# 67  Twilight: Breaking Dawn    Romance   Independent                68
# 68        Midnight in Paris    Romence          Sony                84
# 69                Enchanted     Comedy        Disney                80
#
#     Profitability  Rotten Tomatoes % Worldwide Gross    Year  Rank
# ...

# %%
df2.sort_values("Rank")
# Out:
#                                   Film      Genre            Lead Studio  \
# 41  You Will Meet a Tall Dark Stranger     Comedy            Independent
# 29                        Love Happens      Drama              Universal
# 1                   The Heartbreak Kid     Comedy              Paramount
# 38                        When in Rome     Comedy                 Disney
# 42                             Killers     Action              Lionsgate
# ..                                 ...        ...                    ...
# 7                           Knocked Up     Comedy              Universal
# 59                My Week with Marilyn      Drama  The Weinstein Company
# 68                   Midnight in Paris    Romence                   Sony
# 45                             Tangled  Animation                 Disney
# 17                              WALL-E  Animation                 Disney
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  \
# ...

# %%
df.rename(columns={"Audience score %":"Audience marks"})
# Out:
#                                   Film      Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno    Romance  The Weinstein Company
# 1                      Youth in Revolt     Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger     Comedy            Independent
# 3                         When in Rome     Comedy                 Disney
# 4                What Happens in Vegas     Comedy                    Fox
# ..                                 ...        ...                    ...
# 65                   Gnomeo and Juliet  Animation                 Disney
# 66          Ghosts of Girlfriends Past     Comedy           Warner Bros.
# 67                    Four Christmases     Comedy           Warner Bros.
# 68                           Fireproof      Drama            Independent
# 69                           Enchanted     Comedy                 Disney
#
#     Audience marks  Profitability  Rotten Tomatoes % Worldwide Gross    Year
# ...
