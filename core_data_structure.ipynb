# %%
import pandas as pd

# %%
s1 = pd.Series([91,92,93,94,94])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    91
# 1    92
# 2    93
# 3    94
# 4    94
# dtype: int64

# %%
s2 = pd.Series([91,92,93,94,94], index=["ayush", "rohan", "soham", "piyush", "ojas"])

# %%
s2["ayush"]
# Out:
# np.int64(91)

# %%
s2["rohan"]
# Out:
# np.int64(92)

# %%
data = {
    "name": ["ayush" , "piyush" , "ojas"],
    "age": [12,11,13],
    "city": ["pune" , "mumbai" , "nashik"]
}

# %%
df  = pd.DataFrame(data)

# %%
df
# Out:
#      name  age    city
# 0   ayush   12    pune
# 1  piyush   11  mumbai
# 2    ojas   13  nashik

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
